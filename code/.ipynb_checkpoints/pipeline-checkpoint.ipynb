# %% [markdown]
# # Version 1: Download mod files individually

# %%
# "Transformed dataset URLs (e.g., 'https://modeldb.science/116983?tab=2&file=theta/h.mod') 
# into direct download links ('https://modeldb.science/getModelFile?model=116983&file=theta/h.mod'), 
# appended files with ROWID column from excel (e.g., 'theta/h_ROWID468.mod'), and logged failed downloads."

# %%
import os
import pandas as pd
import requests
from tqdm import tqdm
import re

# Load the dataset
df = pd.read_excel("model_db_annotations.xlsx")

# Ensure the 'mod_files' folder exists
folder_path = "mod_files"
os.makedirs(folder_path, exist_ok=True)

failed_downloads = []

# Function to convert ModelDB URL to direct download URL
def get_direct_download_url(url):
    match = re.search(r"https://modeldb\.science/(\d+)\?tab=2&file=(.+)", url)
    if match:
        model_id, file_path = match.groups()
        return f"https://modeldb.science/getModelFile?model={model_id}&file={file_path}"
    return None  # Return None if the URL doesn't match expected pattern

# Function to download a .mod file
def download_file(url, row_id, folder):
    try:
        direct_url = get_direct_download_url(url)
        if not direct_url:
            print(f"🚨 Skipping invalid URL: {url}")
            failed_downloads.append(url)
            return None

        response = requests.get(direct_url, stream=True, timeout=10)
        response.raise_for_status()

        # Extract original file name
        file_name = os.path.basename(direct_url.split("file=")[-1])
        new_filename = f"{file_name}_ROWID{row_id}.mod"
        save_path = os.path.join(folder, new_filename)

        # Save the file
        with open(save_path, "wb") as file:
            for chunk in tqdm(response.iter_content(chunk_size=8192), desc=f"Downloading {new_filename}", unit="KB"):
                file.write(chunk)
        
        return new_filename
    except requests.exceptions.RequestException as e:
        print(f"❌ Failed to download {direct_url}: {e}")
        failed_downloads.append(url)
        return None

# Select rows from row_id 468 onward and take only the first 10
excel_row = 467
df_subset = df.iloc[excel_row:excel_row+11]

# Process only the first 10 files
for _, row in df_subset.iterrows():
    if "modeldb.science" in row["url"]:  # Ensure it's from ModelDB
        download_file(row["url"], row["row_id"], folder_path)

# Save failed downloads
if failed_downloads:
    pd.DataFrame({"failed_urls": failed_downloads}).to_csv("failed_downloads.csv", index=False)
    print("\n⚠️ Some files failed. Check 'failed_downloads.csv' for details.")

print("\n✅ Download process complete.")

# %% [markdown]
# # Version 2: Download mod files as a single JSON file

# %%
import os
import pandas as pd
import requests
import json
import re
from tqdm import tqdm

# Load dataset from Excel
df = pd.read_excel("model_db_annotations.xlsx")

# Output JSON files
output_json = "mod_files.json"
failed_json = "failed_downloads.json"

# List to store mod file data and failed downloads
mod_files_data = []
failed_downloads = []

# Function to convert ModelDB URL to direct download URL
def get_direct_download_url(url):
    match = re.search(r"https://modeldb\.science/(\d+)\?tab=2&file=(.+)", url)
    if match:
        model_id, file_path = match.groups()
        return f"https://modeldb.science/getModelFile?model={model_id}&file={file_path}", file_path
    return None, None  # Return None if the URL doesn't match the expected pattern

# Function to fetch .mod file content and store in JSON
def fetch_mod_file(row_id, file_hash, raw_sha, count, url):
    direct_url, file_path = get_direct_download_url(url)
    
    # Default structure for JSON entry
    file_entry = {
        "row_id": row_id,
        "file_hash": file_hash,
        "raw_sha": raw_sha,
        "count": count,
        "url": url,
        "download_url": direct_url,
        "content": None  # Default to None (indicating missing content)
    }

    if not direct_url:
        print(f"🚨 Skipping invalid URL: {url}")
        failed_downloads.append(file_entry)
        mod_files_data.append(file_entry)  # Store even failed ones
        return

    try:
        response = requests.get(direct_url, timeout=10)
        response.raise_for_status()
        file_entry["content"] = response.text  # Store the downloaded content
    except requests.exceptions.RequestException as e:
        print(f"❌ Failed to fetch {direct_url}: {e}")
        failed_downloads.append(file_entry)  # Log failed download

    mod_files_data.append(file_entry)  # Store the file entry (success or failure)

# Select rows from 467 (corresponding to row_id 468) and take 11 rows
start = 467
n_rows = 20 
df_subset = df.iloc[start:start+n_rows]

# Process selected files
for _, row in tqdm(df_subset.iterrows(), total=len(df_subset), desc="Fetching .mod files"):
    fetch_mod_file(
        row["row_id"], 
        row["file_hash"], 
        row["raw_sha"], 
        row["count"], 
        row["url"]
    )

# Save all .mod data to JSON (including failed downloads)
with open(output_json, "w", encoding="utf-8") as json_file:
    json.dump(mod_files_data, json_file, indent=4)

# Save failed downloads separately for easy retrying
if failed_downloads:
    with open(failed_json, "w", encoding="utf-8") as json_file:
        json.dump(failed_downloads, json_file, indent=4)
    print(f"⚠️ Some downloads failed. Check {failed_json} for details.")

print(f"\n✅ All .mod files (including failures) saved in {output_json}")
# Out:
# /home/imc33/.conda/envs/nn/lib/python3.11/site-packages/openpyxl/worksheet/_reader.py:329: UserWarning: Data Validation extension is not supported and will be removed
#   warn(msg)
# Fetching .mod files:  20%|██        | 4/20 [00:00<00:01, 15.21it/s]
# ❌ Failed to fetch https://modeldb.science/getModelFile?model=58173&file=b05oct26/na.mod: 403 Client Error: Forbidden for url: https://modeldb.science/getModelFile?model=58173&file=b05oct26/na.mod
# Fetching .mod files: 100%|██████████| 20/20 [00:01<00:00, 15.56it/s]
# ⚠️ Some downloads failed. Check failed_downloads.json for details.
#
# ✅ All .mod files (including failures) saved in mod_files.json

# %% [markdown]
# # Read JSON file

# %%
import os
import pandas as pd
import requests
import json
import re
from bs4 import BeautifulSoup
from tqdm import tqdm

# %%
def View(df, rows=5, cols=None, width=None):
    """Displays the first `rows` of the DataFrame like R's View() by adjusting Pandas settings."""
    
    # Show only the first `rows` of the DataFrame
    with pd.option_context(
        "display.max_rows", rows,  # Limit number of rows shown
        "display.max_columns", cols,  # Show all columns
        "display.max_colwidth", width,  # Show full column width
        "display.expand_frame_repr", False  # Prevent column wrapping
    ):
        display(df.head(rows))  # Show only the first `rows`

# %%
# Function to extract mod directory from the URL
def extract_mod_dir(url):
    match = re.search(r"file=([^/]+)/[^/]+\.mod", url)  # Extract the directory name before the .mod file
    return match.group(1) if match else None  # Return directory name if found, else None

# Function to extract mod file name without extension
def extract_mod_name(url):
    match = re.search(r"/([^/]+)\.mod$", url)  # Get filename without extension
    return match.group(1) if match else None  # Return only the name (e.g., 'na')

# Function to extract model_id from the URL
def extract_model_id(url):
    match = re.search(r"https://modeldb\.science/(\d+)", url)
    return int(match.group(1)) if match else None  # Convert to integer

# Function to determine exclusion reason with snake_case labels
def determine_exclusion(row):
    if pd.isna(row["content"]):
        return "not_found"  # Standardized exclusion for missing files
    if "x86_64" in row["url"]:
        return "x86_64"  # Standardized exclusion for architecture issues
    return None  # Keep valid entries as None (not excluded)

# Function to extract all TITLE occurrences from .mod content
def extract_title(content):
    if pd.isna(content):  # If content is None or NaN, return None
        return None
    matches = re.findall(r"^TITLE\s+(.+)", content, re.MULTILINE)  # Find all TITLE lines
    return matches if matches else None  # Return list if multiple, else None

# Function to extract all COMMENT sections from .mod content
def extract_comment(content):
    if pd.isna(content):  # If content is None or NaN, return None
        return None
    matches = re.findall(r"COMMENT\s+(.*?)\s+ENDCOMMENT", content, re.DOTALL)  # Capture all COMMENT sections
    return matches if matches else None  # Return list if multiple, else None

# Function to extract all SUFFIX occurrences from .mod content
def extract_mod_suffix(content):
    if pd.isna(content):  # If content is None or NaN, return None
        return None
    matches = re.findall(r"SUFFIX\s+(\w+)", content)  # Find all SUFFIX statements
    return matches if matches else None  # Return list if multiple, else None

# Function to extract all USEION occurrences from .mod content
def extract_mod_use_ion(content):
    if pd.isna(content):  # If content is None or NaN, return None
        return None
    matches = re.findall(r"USEION\s+(\w+)", content)  # Find all USEION statements
    return matches if matches else None  # Return list if multiple, else None

# Function to extract webpage heading
def extract_heading(url):
    try:
        response = requests.get(url, timeout=10)  # Fetch the webpage
        response.raise_for_status()
        soup = BeautifulSoup(response.text, "html.parser")
        
        # Try extracting heading from the most relevant tag
        heading = soup.find("h1")  # Look for <h1> (main title)
        return heading.text.strip() if heading else None  # Return text or None
    except requests.exceptions.RequestException:
        return None  # Return None if the request fail

# Function to extract citation (text inside parentheses)
def extract_citation(heading):
    if pd.isna(heading):
        return None
    match = re.search(r"\(([^)]+)\)", heading)  # Find text inside parentheses
    return match.group(1) if match else None  # Extract citation


# Function to extract first author(s) (removes "et al." and "al" correctly)
def extract_first_author(citation):
    if pd.isna(citation):
        return None

    # Extract first author(s) before "et al" or variants
    match = re.search(r"^([\w\s&\-,]+?)(?:\s+et\s+al\.?|et)?(?:,|\s|$)", citation)  
    first_author = match.group(1).strip() if match else None  

    # Remove any trailing "al" left behind
    if first_author:
        first_author = re.sub(r"\b(al)\b", "", first_author, flags=re.IGNORECASE).strip()

    return first_author

def extract_year(citation):
    if pd.isna(citation):
        return None
    match = re.search(r"\b(19|20)\d{2}\b", citation)  # Find a 4-digit year (1900-2099)
    return match.group(0) if match else None  # Extract the year

# %%
# Load JSON into DataFrame
df = pd.read_json("mod_files.json")

# Set "row_id" as the index
df.set_index("row_id", inplace=True)

# Exclude mod files
df["mod_exclude"] = df.apply(determine_exclusion, axis=1)  # Apply exclusion function

# Extract features from url
df["mod_heading"] = df["url"].apply(extract_heading)  # Extract heading from webpage
df["mod_citation"] = df["mod_heading"].apply(extract_citation)
df["mod_first_author"] = df["mod_citation"].apply(extract_first_author)
df["mod_year"] = df["mod_citation"].apply(extract_year)  # Now handles multiple years


df["mod_dir"] = df["url"].apply(extract_mod_dir)
df["mod_name"] = df["url"].apply(extract_mod_name)
df["mod_model_id"] = df["url"].apply(extract_model_id)

#  Extract features from content
df["mod_title"] = df["content"].apply(extract_title)
df["mod_comment"] = df["content"].apply(extract_comment)
df["mod_suffix"] = df["content"].apply(extract_mod_suffix)
df["mod_use_ion"] = df["content"].apply(extract_mod_use_ion)

# %%
df
# Out:
#                                                 file_hash  \
# row_id
# 468     25b50b5441b9a5492122214e0648e0529ec055f2d6e97b...
# 469     3fb039ac47d8004f4d9da9bc3da43bf89ce3e9c632e87d...
# 470     338c3525e3a21e4cdc628b3224a949883cf12b2765f872...
# 471     2ee9ed06c3f7f53d4c4a8f65c4f7ed7c979b810983fa72...
# 472     bcd979facda855ab577dc0cc18f1476bf510c7ac6b642e...
# 473     96526eb4a8f585ecbb64d59a643b0e83bfdc195f8bba6a...
# 474     9bbabc95794782664eff3e6318db36ad8811c38572b48e...
# 475     20308b254cb6bb8a0e7f2db569dd2078b06b1f874dc1c7...
# 476     eaa2b487d69781a92be0b85af13037f3f0036f94971a4c...
# 477     e98f6c4a3598a7cb5e0e9d47d9605d97a8e047b40c6d12...
# 478     22cc8316ed4a6302affa035f391929fed0b43de2ee881b...
# 479     77da4fde0a0b3789281577ae04957f4e550e65fa976c1c...
# 480     eeb5b9e4314b5b6ab9dc8f337b438788ee09bb9f7ab45d...
# 481     4900fc2a839c545f60eee6e005f15798f49bc605aac5a9...
# 482     627cd0389cbab35d72d19e651a0c0dbe5ed75fd44bc1a5...
# 483     b6f00d496b9e87aeb4390f3696a58d3c6c062f451c3a34...
# 484     297fc1dc26d5977cc75298b86944c8ccf3f5bb57b13a92...
# 485     b5c296c33cd92bb76f6fd90123df6e648b627fb31f7da5...
# 486     b4a2398c4068774495deec062cf067783d1676ca340eaa...
# 487     4ede617a0757222db18b8bcc236b059de3c556b279bd78...
#
#                                                   raw_sha  count  \
# row_id
# 468     f81e972ce9d730e924c8280e95395b26346853b9c0b397...      3
# 469     5a432e65a6d72ef8943f0ae6e833100108f341f793c0a0...      1
# 470     e8daa7ec610c947cbfa1bef33e16ba2748e74da7e2596e...      2
# 471     eeb928941300620229779ed4262c41055cac12f7b2fd02...      1
# 472     c5130c699809a9cc9fcd117e6257f56da565fdd1b282bc...      1
# 473     bed60dff2ab3a09598fe1476f782be2bec39a0b686c866...      1
# 474     63ca66c9d9f75f25001ff6a2ff622babc7851813152fb7...      1
# 475     20308b254cb6bb8a0e7f2db569dd2078b06b1f874dc1c7...      1
# 476     1cf926e1537e76053093f7164ebe6383e210d53b184db2...      1
# 477     5a1a10c788db2820d3e40accca04e215f0a056bca5bfbb...      1
# 478     5a8b2acff5f7c9ce89f161c9e555abe813a4e3f813518c...      2
# 479     68db96d2e66613bfc8353e5e3e25281b88f530e3296382...      1
# 480     7c656bdf541743edb420348b705643751366ee14dfda11...      1
# 481     56d3f55557d2a8a0d018c9122c8f3d1cdf94666001b5d8...      1
# 482     c07c72b1e467c8c7dbcdf598df76f58fec0192b606280a...      1
# 483     da5feaaa5614a02d620dbc7fcbf0de1d7f64e14f82a73c...      1
# 484     134e114373de7a5b2ffd0b817744b176b2b6394549adf0...      1
# 485     96ad4fb9b0f124b4c07d3d3b2ab3312c5afb9cd919a63a...      3
# 486     655f776e6ac9fd1834d1d75db6a21a7cf3b391df80eac7...      1
# 487     e8cf6c72e3100bd715e8faf300ceb924f57b0bb63b85dd...      1
#
#                                                       url  \
# row_id
# 468     https://modeldb.science/58173?tab=2&file=b05oc...
# 469     https://modeldb.science/116983?tab=2&file=thet...
# 470     https://modeldb.science/136026?tab=2&file=djur...
# 471     https://modeldb.science/18502?tab=2&file=spine...
# 472     https://modeldb.science/256140?tab=2&file=Luqu...
# 473     https://modeldb.science/82894?tab=2&file=nrntr...
# 474     https://modeldb.science/168858?tab=2&file=Cosk...
# 475     https://modeldb.science/249705?tab=2&file=plat...
# 476     https://modeldb.science/256024?tab=2&file=Dewe...
# 477     https://modeldb.science/266818?tab=2&file=Vent...
# 478     https://modeldb.science/124394?tab=2&file=nevi...
# 479     https://modeldb.science/141272?tab=2&file=DAmo...
# 480     https://modeldb.science/222321?tab=2&file=Gent...
# 481     https://modeldb.science/267511?tab=2&file=S1_T...
# 482     https://modeldb.science/28316?tab=2&file=OLMmo...
# 483     https://modeldb.science/195666?tab=2&file=Dewe...
# 484     https://modeldb.science/83547?tab=2&file=damod...
# 485     https://modeldb.science/2014998?tab=2&file=DG-...
# 486     https://modeldb.science/181967?tab=2&file=Cuts...
# 487     https://modeldb.science/223891?tab=2&file=Conn...
#
#                                              download_url  \
# row_id
# 468     https://modeldb.science/getModelFile?model=581...
# 469     https://modeldb.science/getModelFile?model=116...
# 470     https://modeldb.science/getModelFile?model=136...
# 471     https://modeldb.science/getModelFile?model=185...
# 472     https://modeldb.science/getModelFile?model=256...
# 473     https://modeldb.science/getModelFile?model=828...
# 474     https://modeldb.science/getModelFile?model=168...
# 475     https://modeldb.science/getModelFile?model=249...
# 476     https://modeldb.science/getModelFile?model=256...
# 477     https://modeldb.science/getModelFile?model=266...
# 478     https://modeldb.science/getModelFile?model=124...
# 479     https://modeldb.science/getModelFile?model=141...
# 480     https://modeldb.science/getModelFile?model=222...
# 481     https://modeldb.science/getModelFile?model=267...
# 482     https://modeldb.science/getModelFile?model=283...
# 483     https://modeldb.science/getModelFile?model=195...
# 484     https://modeldb.science/getModelFile?model=835...
# 485     https://modeldb.science/getModelFile?model=201...
# 486     https://modeldb.science/getModelFile?model=181...
# 487     https://modeldb.science/getModelFile?model=223...
#
#                                                   content mod_exclude  \
# row_id
# 468                                                  None   not_found
# 469     TITLE I-h channel from Magee 1998 for distal d...        None
# 470     \nCOMMENT\n\nna.mod\n\nSodium channel, Hodgkin...        None
# 471     \r\nCOMMENT\na synaptic current with NMDA func...        None
# 472     TITLE Purkinje simplified Cell model\r\n\r\nCO...        None
# 473     COMMENT\nFour helpful hints:\n\n1) before call...        None
# 474     TITLE Potasium dr type current for RD Traub, J...        None
# 475                                      ../glutamate.mod      x86_64
# 476     NEURON {\n   POINT_PROCESS Gap\n   POINTER vga...        None
# 477     TITLE Mod file for component: Component(id=gen...        None
# 478     COMMENT\r\n//****************************//\r\...        None
# 479     COMMENT\r\nOriginal Hodgkin and Huxley model (...        None
# 480     TITLE accum :Ion accumulation, potassium buffe...        None
# 481     COMMENT\n/**\n * @file ProbAMPANMDA_EMS.mod\n ...        None
# 482     TITLE simple AMPA receptors\n\nCOMMENT\n------...        None
# 483     TITLE Ca2+ deinactivated K-D channel from RBD\...        None
# 484     TITLE GKCA\n \n\nUNITS {\n       (molar) = (1/...        None
# 485     : \tHigh threshold potassium chanel from \n:\t...        None
# 486     TITLE T-calcium channel\r\n: T-type calcium ch...        None
# 487     TITLE I-h channel for Thalamic neurons from Mc...        None
#
#                                               mod_heading  \
# row_id
# 468                                                  None
# 469     CA1 pyramidal neuron: h channel-dependent defi...
# 470     Functional structure of mitral cell dendritic ...
# 471     Spine fusion and branching affects synaptic re...
# 472     Spike burst-pause dynamics of Purkinje cells r...
# 473     A single column thalamocortical network model ...
# 474     Rhesus Monkey Layer 3 Pyramidal Neurons: Young...
# 475     Glutamate mediated dendritic and somatic plate...
# 476               LGMD impedance (Dewell & Gabbiani 2019)
# 477     FHF2KO and Wild-Type Mouse Cardiomyocyte Stran...
# 478     Dendritic Na+ spike initiation and backpropaga...
# 479     Simple and accurate Diffusion Approximation al...
# 480     Changes of ionic concentrations during seizure...
# 481     Biophysically detailed model of somatosensory ...
# 482     Active dendrites and spike propagation in a hi...
# 483     LGMD with 3D morphology and active dendrites (...
# 484     Regulation of the firing pattern in dopamine n...
# 485     Frequency-dependent pattern separation in a bi...
# 486     Long time windows from theta modulated inhib. ...
# 487     Rat LGN Thalamocortical Neuron (Connelly et al...
#
#                      mod_citation mod_first_author mod_year  \
# row_id
# 468                          None             None     None
# 469          Marcelin et al. 2008         Marcelin     2008
# 470          Djurisic et al. 2008         Djurisic     2008
# 471      Rusakov et al 1996, 1997          Rusakov     1996
# 472              Luque et al 2019            Luque     2019
# 473              Traub et al 2005            Traub     2005
# 474           Coskren et al. 2015          Coskren     2015
# 475                 Gao et al '20              Gao     None
# 476        Dewell & Gabbiani 2019           Dewell     2019
# 477               Park et al 2020             Park     2020
# 478            Nevian et al. 2007           Nevian     2007
# 479            Orio & Soudry 2012             Orio     2012
# 480        Gentiletti et al. 2016       Gentiletti     2016
# 481                          None             None     None
# 482             Saraga et al 2003           Saraga     2003
# 483        Dewell & Gabbiani 2018           Dewell     2018
# 484        Komendantov et al 2004      Komendantov     2004
# 485            Singh et al., 2023            Singh     2023
# 486     Cutsuridis & Poirazi 2015       Cutsuridis     2015
# 487     Connelly et al 2015, 2016         Connelly     2015
#
#                                 mod_dir          mod_name  mod_model_id  \
# row_id
# 468                            b05oct26                na         58173
# 469                               theta                 h        116983
# 470                        djurisic2008                na        136026
# 471                       spinebranches           nmdasyn         18502
# 472                                None           Purk_gM        256140
# 473                                None                ri         82894
# 474                     CoskrenEtAl2015               kdr        168858
# 475                                None         glutamate        249705
# 476                                None               gap        256024
# 477     Ventricular_GUI.CircRes.ModelDB               Kss        266818
# 478                              nevian    double_synapse        124394
# 479                                None            hh58F1        141272
# 480                  GentilettiEtAl2016             accum        222321
# 481                                None  ProbAMPANMDA_EMS        267511
# 482                            OLMmodel              ampa         28316
# 483                                None       LGMD_KD_ca3        195666
# 484                             damodel               kca         83547
# 485                                None                HT       2014998
# 486               CutsuridisPoirazi2015              cat3        181967
# 487               ConnellyEtAl2015_2016               htc        223891
#
#                                                 mod_title  \
# row_id
# 468                                                  None
# 469     [I-h channel from Magee 1998 for distal dendri...
# 470                                                  None
# 471                                                  None
# 472                    [Purkinje simplified Cell model\r]
# 473                                                  None
# 474     [Potasium dr type current for RD Traub, J Neur...
# 475                                                  None
# 476                                                  None
# 477     [Mod file for component: Component(id=generate...
# 478                                    [double synapse\r]
# 479                                                  None
# 480     [accum :Ion accumulation, potassium buffering ...
# 481     [Probabilistic AMPA and NMDA receptor with pre...
# 482                               [simple AMPA receptors]
# 483             [Ca2+ deinactivated K-D channel from RBD]
# 484                                                [GKCA]
# 485                                                  None
# 486                                 [T-calcium channel\r]
# 487     [I-h channel for Thalamic neurons from McCormi...
#
#                                               mod_comment  mod_suffix  \
# row_id
# 468                                                  None        None
# 469                                                  None        [hd]
# 470     [na.mod\n\nSodium channel, Hodgkin-Huxley styl...        [na]
# 471     [a synaptic current with NMDA function conduct...        None
# 472     [kM channel\r\n        \r\n        Authors: Ni...  [Purk_gKM]
# 473     [Four helpful hints:\n\n1) before calling scal...   [nothing]
# 474     [Implemented by Aniruddha Yadav 2007 (aniruddh...       [kdr]
# 475                                                  None        None
# 476                                                  None        None
# 477     [This NEURON file has been generated by org.ne...       [Kss]
# 478     [//****************************//\r\n// Create...        None
# 479     [Original Hodgkin and Huxley model (J.Physiol....    [hh58F1]
# 480                                                  None     [accum]
# 481     [/**\n * @file ProbAMPANMDA_EMS.mod\n * @brief...        None
# 482     [---------------------------------------------...        None
# 483                                                  None    [KD_ca3]
# 484                      [INITIAL{\n       cai = cainit}]      [gkca]
# 485                                                  None        [HT]
# 486                                                  None      [cat3]
# 487                                                  None       [htc]
#
#             mod_use_ion
# row_id
# 468                None
# 469                None
# 470                [na]
# 471                None
# 472                 [k]
# 473                None
# 474                 [k]
# 475                None
# 476                None
# 477                 [k]
# 478                None
# 479             [na, k]
# 480     [na, k, ca, cl]
# 481                None
# 482                None
# 483             [k, ca]
# 484             [ca, k]
# 485                 [k]
# 486                [ca]
# 487                None

# %%
View(df,3)

# %%
sample = """ 
TITLE K-Cl cotransporter KCC2

INDEPENDENT {t FROM 0 TO 1 WITH 10 (ms)}

NEURON {
	SUFFIX kcc2
	USEION k READ ko, ki WRITE ik
	USEION cl READ clo, cli WRITE icl VALENCE -1
	RANGE ik, icl
	GLOBAL U, S, Vi
}

UNITS {
	(mV)	= (millivolt)
	(molar) = (1/liter)
	(mM)	= (millimolar)
	(um)	= (micron)
	(mA)	= (milliamp)
	(mol)	= (1)
	FARADAY	= 96485.309 (coul/mole)
	PI	= (pi) (1)
}

PARAMETER {
	S = 5654.87 (um2)
  	Vi = 8913.48 (um3)
	U = 0.0003    (mM/ms)
}

ASSIGNED {
	ik		(mA/cm2)
	icl		(mA/cm2)
	ko		(mM)
	ki		(mM)
  	clo   (mM)
  	cli   (mM)
}

BREAKPOINT {
	LOCAL rate
	rate = pumprate(ki,ko,cli,clo)
	ik =  rate
	icl = -rate
}

FUNCTION pumprate(ki,ko,cli,clo) {
	pumprate = U*log((ki*cli)/(ko*clo))*(FARADAY*Vi/(S*1e4))
}
"""

# %%
extract_mod_use_ion(sample)
