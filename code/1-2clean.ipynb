# %% [markdown]
# # Import Libaries and Functions

# %%
from _utils import *

# %% [markdown]
# ##  Google Sheet Label Data

# %%
# Open the sheet by name
sheet = client.open("label_df").sheet1

# Read sheet data into DataFrame
data = sheet.get_all_records()
label_df = pd.DataFrame(data)

label_df_long = (
    label_df
    .assign(
        robert_subtype_label=label_df['robert_subtype_label']
        .str.split(' \|\| ')
    )
    .explode('robert_subtype_label')
    .assign(
        robert_subtype_label=lambda df: df['robert_subtype_label']
        .str.strip()
        .replace("", pd.NA)
    )
)

# %% [markdown]
# ## Subtypes that the GPT dataset is missing

# %% [markdown]
# - All of them are custom subtypes except for I Other (Modulator-Activated)

# %%
INNA_SUBTYPES_ONLY = label_df.query("robert_subtype_label == ''")["original_subtype_label"].tolist()

# %%
INNA_SUBTYPES_ONLY
# Out:
# ['Exclude - Not on Model DB',
#  'Exclude - Old Architecture',
#  'Exclude - Accumulation Mechanism',
#  'I Ca (HVA)',
#  'I K (Ultra Rapid Shaker-related Cardiac)',
#  'I K (Resistent Persistent)',
#  'I Kx (Photoreceptor)',
#  'I Na (Resurgent)',
#  'I Leak (General)',
#  'I Other (Modulator-Activated)',
#  'Neither - Utility',
#  'Neither - Non-Neural',
#  'Neither - Clamp',
#  'Neither - Accumulation Mechanism',
#  'Neither - Localized Reactions',
#  'Neither - Artificial Cell',
#  'Neither - Gap Junction']

# %%
XZ_SUBTYPES = label_df.query("original_type_label in ['Exclude','Neither']")["original_subtype_label"].tolist()
XZ_SUBTYPES
# Out:
# ['Exclude - Not on Model DB',
#  'Exclude - Old Architecture',
#  'Exclude - Accumulation Mechanism',
#  'Neither - Utility',
#  'Neither - Non-Neural',
#  'Neither - Clamp',
#  'Neither - Accumulation Mechanism',
#  'Neither - Localized Reactions',
#  'Neither - Artificial Cell',
#  'Neither - Gap Junction']

# %% [markdown]
# ## Subtypes that Annotation Set is missing

# %%
label_df.query("gpt_only == 'y'")
# Out:
#    original_type_label       original_subtype_label  \
# 51             I Other  I Other (NKCC1 Transporter)
# 54             I Other       I Other (Na Glutamate)
# 55             I Other           I TRP (M4-subtype)
# 63          R Dopamine              R Dopamine (D1)
# 65         R Glutamate        R Glutamate (Kainate)
# 66           R Sensory         R Sensory  (General)
# 67             R Other                R Other - IP3
#
#          robert_subtype_label      new_subtype_label gpt_only
# 51                      NKCC1  I Other (Transporter)        y
# 54  Na+-glutamate transporter  I Other (Transporter)        y
# 55            I TRPM4                 I Other (Rare)        y
# 63                         D1         R Other (Rare)        y
# 65                    Kainate         R Other (Rare)        y
# 66          Sensory Receptors         R Other (Rare)        y
# 67                        IP3         R Other (Rare)        y

# %% [markdown]
# ## JSON File

# %%
json_df = pd.read_json("../data/raw/mod_files.json")

# %%
json_df
# Out:
#       row_id                                          file_hash  \
# 0          1  f8be35d0c20d1b1f3de4c44323e1780ee24f06893b6364...
# 1          2  e97ca8a7f9734805832e5ae75442d19d3d7796b9a24190...
# 2          3  b428f4a84f4302dd5e9139beb678039621e4ee5e88b780...
# 3          4  606423f8f4a4f406f3387c7ee6f142bd121237272c347d...
# 4          5  99713c0032634e96cc7cde2dce02d8aa2baf75ad4cc835...
# ...      ...                                                ...
# 5128    5129  79b0488211bde2819176d272a3baf1ea494f7a15b602a7...
# 5129    5130  d8008fe9dc4f90a8bb5484995e07190bda986f48d36bd2...
# 5130    5131  026e11a7203d24881dcf93b0c7c7fb7d15e6b7dd3d03d4...
# 5131    5132  e772fbe270f6fca1c2ee2c7df9a509b4b92ae03bc33cec...
# 5132    5133  a9a9d90c28540c114fd8617df170b069cc586eb40b24cb...
#
#                                                 raw_sha  count  \
# 0     67b75245b9690ce219f34a5905425672dcb5c0661a885f...      6
# 1     b45c13164f1eeaf4ba61ee8522304f7382fa0541831b1a...      1
# 2     b720bf29848dde82785dd101105f185ebcf9affa081dfd...      1
# 3     81645a02d4dbf324cf8b82e8f31bda2ce46c3753f7a8ac...      1
# 4     5fe32f050754f534d60c7c126ecd805216089cd0594062...      1
# ...                                                 ...    ...
# 5128  7d66f936b9aff684c32bf25234f39c9e755d0fcda38a57...      9
# 5129  309c68434d3809f6fd2d547a9869f202800320cc6e7a52...      1
# 5130  8f8e9c80af3b9d715be639e6fa40670269332ae9bc264e...      1
# 5131  611ae45451e170f8efed72e9f62bae93774a9e2bb9338a...      3
# 5132  256544e26c85c9108832faff4d57a9f70859e58beeab03...      6
#
#                                                     url  \
# 0     https://modeldb.science/183300?tab=2&file=Shor...
# 1     https://modeldb.science/223649?tab=2&file=Altu...
# 2     https://modeldb.science/3511?tab=2&file=mcn1/m...
# 3     https://modeldb.science/262115?tab=2&file=demo...
# 4     https://modeldb.science/150288?tab=2&file=KimE...
# ...                                                 ...
# 5128  https://modeldb.science/65218?tab=2&file=nrntr...
# 5129  https://modeldb.science/266989?tab=2&file=VMTh...
# 5130  https://modeldb.science/194897?tab=2&file=Dura...
# 5131  https://modeldb.science/231427?tab=2&file=repr...
# 5132  https://modeldb.science/266799?tab=2&file=PRC_...
#
#                                            download_url  \
# 0     https://modeldb.science/getModelFile?model=183...
# 1     https://modeldb.science/getModelFile?model=223...
# 2     https://modeldb.science/getModelFile?model=351...
# 3     https://modeldb.science/getModelFile?model=262...
# 4     https://modeldb.science/getModelFile?model=150...
# ...                                                 ...
# 5128  https://modeldb.science/getModelFile?model=652...
# 5129  https://modeldb.science/getModelFile?model=266...
# 5130  https://modeldb.science/getModelFile?model=194...
# 5131  https://modeldb.science/getModelFile?model=231...
# 5132  https://modeldb.science/getModelFile?model=266...
#
#                                                 content error_code
# 0     TITLE Sodium persistent current\n\nCOMMENT\n  ...       None
# 1     TITLE K-A channel from Klee Ficker and Heinema...       None
# 2     INDEPENDENT {t FROM 0 TO 1 WITH 1 (ms)}\n\nNEU...       None
# 3     TITLE multiple GABAa receptors\n\nCOMMENT\n---...       None
# 4     :Interneuron Cells to Pyramidal Cells GABA wit...       None
# ...                                                 ...        ...
# 5128                                               None        403
# 5129  TITLE Hippocampal HH channels\n: \n:\n: Fast N...       None
# 5130  : $Id: nsloc.mod,v 1.7 2013/06/20  salvad $\n:...       None
# 5131  TITLE AMPA receptor-one of the two input stimu...       None
# 5132  TITLE Voltage-gated low threshold potassium cu...       None
#
# [5133 rows x 8 columns]

# %% [markdown]
# ## Annotated Excel Sheet

# %%
fp = "../data/raw/model_db_annotations.xlsx"
raw_ant_df_wide = pd.read_excel(fp).query("annotated == 'y'")

missing_subtype1_df = raw_ant_df_wide[raw_ant_df_wide["subtype_1"].isna()]

raw_ant_df_long = (raw_ant_df_wide
    .melt(
        id_vars=[col for col in raw_ant_df_wide.columns if col not in ['subtype_1', 'subtype_2', 'subtype_3', 'subtype_4', 'subtype_5']],
        value_vars=['subtype_1', 'subtype_2', 'subtype_3', 'subtype_4', 'subtype_5'],
        var_name="subtype_num",
        value_name="original_subtype_label"
    ))


ant_df_long = (raw_ant_df_long
    .dropna(subset=["original_subtype_label"])
    #Exclusion Criteria here 
    .query("subtype_confidence != '1 - Not confident at all'")
    .query("type != 'Exclude'")
    .drop(columns=['raw_sha','count','url','mod_file','ask_robert','annotated','Robert reviewed','subtype_num'])
    .merge(label_df, on="original_subtype_label", how="left")
    .sort_values('row_id')
    .query("type != 'I Multi'")
    .query("type != 'R Multi'")
    ).drop(columns=["robert_subtype_label"])
# Out:
# /home/imc33/.conda/envs/nn/lib/python3.11/site-packages/openpyxl/worksheet/_reader.py:329: UserWarning: Conditional Formatting extension is not supported and will be removed
# /home/imc33/.conda/envs/nn/lib/python3.11/site-packages/openpyxl/worksheet/_reader.py:329: UserWarning: Data Validation extension is not supported and will be removed

# %%
raw_ant_df_long.to_csv("../data/pipeline/ant_with_excluded_samples.csv")

# %% [markdown]
# ## GPT-4
# - These are the subtypes present in our 1k annotation set that are missing from GPT
# - Not shown, the GPT dataset included the following: "D1', 'D2', 'Dopaminergic Receptor', 'M1', 'M2', 'M3', 'M4'" which are missing form our 1k dataset

# %%
raw_raw_gpt_df = pd.read_csv("../data/raw/mod_files_gpt.csv")

# %%
raw_gpt_df = pd.read_csv("../data/raw/mod_files_gpt.csv", usecols=["hash","currents_at_least_3"]).rename(columns={"currents_at_least_3":"gpt_pred"})
raw_gpt_df.head()
# Out:
#                                                 hash  \
# 0  cf53b079807fc6711d9563031aae227dd1a73cf5add973...
# 1  04c32cd101754ad7f2eaf278919c6ce85b8a7d67149fca...
# 2  2d3c5c121271cfad6d2e35db7d2c418de64f97e57c20a0...
# 3  e2f71ea16f8378b3cf0670f9bd5e457634824ab9ee8a7c...
# 4  04860f65d331d381e779e488566f95ab0e1fa4960b50a7...
#
#                                            gpt_pred
# 0                                       ["IK Skca"]
# 1  ["I Potassium", "I Calcium", "NMDA", "I Sodium"]
# 2                             ["I T low threshold"]
# 3                                           ["I K"]
# 4                                                []

# %%
#'D1', 'D2', 'Dopaminergic Receptor', 'M1', 'M2', 'M3', 'M4'
#label_df_long[label_df_long.robert_subtype_label.isna()]

# %%
ANNOTATED_SAMPLES = ant_df_long["file_hash"].tolist()

# %%
len(ANNOTATED_SAMPLES)
# Out:
# 1021

# %%
gpt_df2 = (
    raw_gpt_df
    .query("hash in @ANNOTATED_SAMPLES")
    .assign(
        gpt_pred=lambda df: df["gpt_pred"].apply(
            lambda x: ast.literal_eval(x) if isinstance(x, str) else x
        )
    )
    .explode("gpt_pred", ignore_index=True)
    .assign(gpt_pred=lambda df: df["gpt_pred"].apply(lambda x: x.strip() if isinstance(x, str) else x))
    .assign(gpt_pred=lambda df: df["gpt_pred"].replace("", pd.NA))
    .dropna(subset=["gpt_pred"])  # <-- drop rows where gpt_pred is NA
    .merge(label_df_long, how="left", left_on="gpt_pred", right_on="robert_subtype_label")          
)

# %%
gpt_df2
# Out:
#                                                   hash           gpt_pred  \
# 0    cf53b079807fc6711d9563031aae227dd1a73cf5add973...            IK Skca
# 1    f93e2a97461e26fd22b4a0306da98ccdcc65858623a336...                I K
# 2    241fe560ad656781054be429af7c5cee507bae0a0383c8...                Kir
# 3    32825343680dec678864c7c0be7164772f152f51be1878...            Ca pump
# 4    67082462e039c1300522e57313f509a1987e2988a20457...        I Potassium
# ..                                                 ...                ...
# 755  3c251d45f8747a637de413c987d0c55aa3cd90fa9564d4...                I A
# 756  353958b6a829992f9c5216e0c879a23ca3d4ffc319774e...              GabaA
# 757  49786cb42f51c10c434dd06e34f157ff9134b5c8758ad5...              GabaB
# 758  fc65c9b5c0fb86232d07e57c29d1cb3efe27821b224208...             I Na,t
# 759  b408003421870590bb819f81765f2bd5b9f2f90102b5f3...  I T low threshold
#
#     original_type_label   original_subtype_label robert_subtype_label  \
# 0                   I K  I K (Ca-Activated - Sk)              IK Skca
# 1                   I K  I K (Delayed Rectifier)                  I K
# 2                   I K                 I K (IR)                  Kir
# 3                  I Ca           I Ca (Ca Pump)              Ca pump
# 4                   I K            I K (General)          I Potassium
# ..                  ...                      ...                  ...
# 755                 I K   I K (A-Type Transient)                  I A
# 756              R GABA          R GABA (type A)                GabaA
# 757              R GABA          R GABA (type b)                GabaB
# 758                I Na         I Na (Transient)               I Na,t
# 759                I Ca         I Ca (T-type LT)    I T low threshold
#
#            new_subtype_label gpt_only
# 0         I K (Ca-activated)
# 1    I K (Delayed Rectifier)
# 2                 I K (Rare)
# 3                I Ca (Rare)
# 4                 I K (Rare)
# ..                       ...      ...
# 755             I K (A-type)
# 756                   R GABA
# 757                   R GABA
# 758         I Na (Transient)
# 759         I Ca (T-type LT)
#
# [760 rows x 7 columns]

# %% [markdown]
# ## GPT predicted mixes for these (#todo)

# %%
View(gpt_df2[gpt_df2.hash.duplicated(keep=False)].sort_values("hash"))
# Out:
#                                                                  hash            gpt_pred original_type_label        original_subtype_label robert_subtype_label        new_subtype_label gpt_only
# 496  009c5ef10778371f25f95c9ad812c6f628c8f2a7bd7f0638d151bce8c9b4ec06         I Potassium                 I K                 I K (General)          I Potassium               I K (Rare)
# 494  009c5ef10778371f25f95c9ad812c6f628c8f2a7bd7f0638d151bce8c9b4ec06                NMDA         R Glutamate            R Glutamate (NMDA)                 NMDA       R Glutamate (NMDA)
# 495  009c5ef10778371f25f95c9ad812c6f628c8f2a7bd7f0638d151bce8c9b4ec06           I Calcium                I Ca                I Ca (General)            I Calcium              I Ca (Rare)
# 351  04fdb27c5f82a7ebeb4cc1f5ddd7d02d6f3f638e740c1e77c7ec261364390a22               GabaB              R GABA               R GABA (type b)                GabaB                   R GABA
# 350  04fdb27c5f82a7ebeb4cc1f5ddd7d02d6f3f638e740c1e77c7ec261364390a22               GabaA              R GABA               R GABA (type A)                GabaA                   R GABA
# 172  0e8bdecd6d7f215aa757f7bc7eb77b993ea69333cbd59b47ebcdd4ffeb61c139         I Potassium                 I K                 I K (General)          I Potassium               I K (Rare)
# 173  0e8bdecd6d7f215aa757f7bc7eb77b993ea69333cbd59b47ebcdd4ffeb61c139            I Sodium                I Na                I Na (General)             I Sodium           I Na (General)
#
# 600  e92d01894fb69379e1c601a50404ef51979cdf6c2876c60495f814a58a4d081f     Na/Ca exchanger             I Other     I Other (Na/Ca exchanger)      Na/Ca exchanger    I Other (Transporter)
# 599  e92d01894fb69379e1c601a50404ef51979cdf6c2876c60495f814a58a4d081f             Ca pump                I Ca                I Ca (Ca Pump)              Ca pump              I Ca (Rare)
# 446  eeb5b9e4314b5b6ab9dc8f337b438788ee09bb9f7ab45d00cfc86437d374290f         I Potassium                 I K                 I K (General)          I Potassium               I K (Rare)
# 449  eeb5b9e4314b5b6ab9dc8f337b438788ee09bb9f7ab45d00cfc86437d374290f            I Sodium                I Na                I Na (General)             I Sodium           I Na (General)
# 447  eeb5b9e4314b5b6ab9dc8f337b438788ee09bb9f7ab45d00cfc86437d374290f           I Calcium                I Ca                I Ca (General)            I Calcium              I Ca (Rare)
# 448  eeb5b9e4314b5b6ab9dc8f337b438788ee09bb9f7ab45d00cfc86437d374290f          I Chloride                I Cl                I Cl (General)           I Chloride                    I Cl

# %%
a = set(gpt_df2["hash"])
b = set(ANNOTATED_SAMPLES)

# %%
MISSING_IN_GPT = list(b-a)

# %%
missing_gpt_df = pd.DataFrame({
    "hash": MISSING_IN_GPT,
    "gpt_pred_subtype": "Z Neither",
    "gpt_pred_type": "Neither"
})

# %%
missing_gpt_df
# Out:
#                                                   hash gpt_pred_subtype  \
# 0    976c2c7b5b0705a376f0a1ff29495e7fe0069d99511831...        Z Neither
# 1    3d81c69104a2de304afcbd7fe7696eb82bd7e67b9e1357...        Z Neither
# 2    4375ed0f480cbe4572e4b30abcffe052bed63a65aa0265...        Z Neither
# 3    1bad59a8ec3db53c72309760b203920cbf091ee4663c58...        Z Neither
# 4    9ce2c80b5bd5b8910d2524ec7e6a147d65384d633eb938...        Z Neither
# ..                                                 ...              ...
# 303  a5c0a068f57399a6dbce8e599f6e6caca65a3929f119c5...        Z Neither
# 304  a8f449da2d03d1f812909c79ba27ae47a3b542794f4ced...        Z Neither
# 305  37bfe228042f79b485a50636a420726a46582a46f4e422...        Z Neither
# 306  9bbabc95794782664eff3e6318db36ad8811c38572b48e...        Z Neither
# 307  1445ed3ff2af6e46578eb3ffba99d803a964c46ec74d99...        Z Neither
#
#     gpt_pred_type
# 0         Neither
# 1         Neither
# 2         Neither
# 3         Neither
# 4         Neither
# ..            ...
# 303       Neither
# 304       Neither
# 305       Neither
# 306       Neither
# 307       Neither
#
# [308 rows x 3 columns]

# %%
#gpt_counts = check_map(gpt_df2, "original_subtype_label", "gpt_pred")
#gpt_counts.query("original_subtype_label not in @XZ_SUBTYPES").sort_values("n", ascending=False)
#gpt_counts.query("original_subtype_label not in @XZ_SUBTYPES").query("n <=20").sort_values("n", ascending=False)

# %%
RARE_SUBTYPES_GPT = gpt_df2["new_subtype_label"].value_counts().reset_index().query("count <=10")["new_subtype_label"].tolist()

# %%
RARE_SUBTYPES_GPT
# Out:
# ['I K (Leak)', 'I Cl ', 'R Other (Rare)', 'I Na (Rare)', 'I Na (Leak)']

# %%
#todo: NA general,  I Other Nonspecific, I Delayed Recifidwer

# %%
gpt_df2
# Out:
#                                                   hash           gpt_pred  \
# 0    cf53b079807fc6711d9563031aae227dd1a73cf5add973...            IK Skca
# 1    f93e2a97461e26fd22b4a0306da98ccdcc65858623a336...                I K
# 2    241fe560ad656781054be429af7c5cee507bae0a0383c8...                Kir
# 3    32825343680dec678864c7c0be7164772f152f51be1878...            Ca pump
# 4    67082462e039c1300522e57313f509a1987e2988a20457...        I Potassium
# ..                                                 ...                ...
# 755  3c251d45f8747a637de413c987d0c55aa3cd90fa9564d4...                I A
# 756  353958b6a829992f9c5216e0c879a23ca3d4ffc319774e...              GabaA
# 757  49786cb42f51c10c434dd06e34f157ff9134b5c8758ad5...              GabaB
# 758  fc65c9b5c0fb86232d07e57c29d1cb3efe27821b224208...             I Na,t
# 759  b408003421870590bb819f81765f2bd5b9f2f90102b5f3...  I T low threshold
#
#     original_type_label   original_subtype_label robert_subtype_label  \
# 0                   I K  I K (Ca-Activated - Sk)              IK Skca
# 1                   I K  I K (Delayed Rectifier)                  I K
# 2                   I K                 I K (IR)                  Kir
# 3                  I Ca           I Ca (Ca Pump)              Ca pump
# 4                   I K            I K (General)          I Potassium
# ..                  ...                      ...                  ...
# 755                 I K   I K (A-Type Transient)                  I A
# 756              R GABA          R GABA (type A)                GabaA
# 757              R GABA          R GABA (type b)                GabaB
# 758                I Na         I Na (Transient)               I Na,t
# 759                I Ca         I Ca (T-type LT)    I T low threshold
#
#            new_subtype_label gpt_only
# 0         I K (Ca-activated)
# 1    I K (Delayed Rectifier)
# 2                 I K (Rare)
# 3                I Ca (Rare)
# 4                 I K (Rare)
# ..                       ...      ...
# 755             I K (A-type)
# 756                   R GABA
# 757                   R GABA
# 758         I Na (Transient)
# 759         I Ca (T-type LT)
#
# [760 rows x 7 columns]

# %%
gpt_df3 = (
    pd.concat(
        [
            gpt_df2
                .drop(columns=["gpt_pred", "robert_subtype_label", "original_subtype_label","gpt_only"])
                .rename(columns={
                    "new_subtype_label": "gpt_pred_subtype",
                    "original_type_label": "gpt_pred_type"
                }),
            missing_gpt_df
        ],
        ignore_index=True
    )
)

# %%
gpt_df3
# Out:
#                                                    hash gpt_pred_type  \
# 0     cf53b079807fc6711d9563031aae227dd1a73cf5add973...           I K
# 1     f93e2a97461e26fd22b4a0306da98ccdcc65858623a336...           I K
# 2     241fe560ad656781054be429af7c5cee507bae0a0383c8...           I K
# 3     32825343680dec678864c7c0be7164772f152f51be1878...          I Ca
# 4     67082462e039c1300522e57313f509a1987e2988a20457...           I K
# ...                                                 ...           ...
# 1063  a5c0a068f57399a6dbce8e599f6e6caca65a3929f119c5...       Neither
# 1064  a8f449da2d03d1f812909c79ba27ae47a3b542794f4ced...       Neither
# 1065  37bfe228042f79b485a50636a420726a46582a46f4e422...       Neither
# 1066  9bbabc95794782664eff3e6318db36ad8811c38572b48e...       Neither
# 1067  1445ed3ff2af6e46578eb3ffba99d803a964c46ec74d99...       Neither
#
#              gpt_pred_subtype
# 0          I K (Ca-activated)
# 1     I K (Delayed Rectifier)
# 2                  I K (Rare)
# 3                 I Ca (Rare)
# 4                  I K (Rare)
# ...                       ...
# 1063                Z Neither
# 1064                Z Neither
# 1065                Z Neither
# 1066                Z Neither
# 1067                Z Neither
#
# [1068 rows x 3 columns]

# %% [markdown]
# ## Simulation Features

# %%
#todo: remember to change this when we move to the project directory
base_dir = Path("/vast/palmer/scratch/mcdougal/imc33/mod-extract/data/raw/")
folder_path = base_dir / "sim_csvs"

# Read & combine all CSVs
dfs = []
for file in folder_path.glob("*.csv"):
    df = pd.read_csv(file)
    df["source_file"] = file.name
    df["source_folder"] = folder_path.name
    df["mod_file"] = file.stem.split("__")[-1]
    dfs.append(df)

if not dfs:
    raise FileNotFoundError(f"No CSV files found in {folder_path}")

# Concatenate and drop duplicates
combined_df = pd.concat(dfs, ignore_index=True).drop_duplicates()

# Save combined file
out_path = base_dir / "sim_features_combined.csv"
combined_df.to_csv(out_path, index=False)
print(f"Saved combined sim features to {out_path}")
# Out:
# Saved combined sim features to /vast/palmer/scratch/mcdougal/imc33/mod-extract/data/raw/sim_features_combined.csv

# %%
combined_df = pd.read_csv("../data/raw/sim_features_combined.csv")

# %%
sim_df = (
    combined_df
    .drop_duplicates(subset="mod_file")
    .rename(columns=lambda col: col if col in ['mod_file', 'mod_name'] else f"{col}_simfeat")
    .assign(file_hash=lambda df: df['mod_file'].str.replace(r'\.mod$', '', regex=True))
    .drop(columns=["suffix_simfeat","source_file_simfeat","source_folder_simfeat"])
    .reset_index(drop=True)
)

# %%
sim_df.shape
# Out:
# (569, 51)

# %% [markdown]
# # Check Rare Labels
# - If count < 10, then collapse into another category; if no category fits, then collapse into Rare. If the collapsed subtype is still rare after collapsing then remove.
# - These are the subtypes that were rare before the extra annotation in 2025-06-27:
# - RARE_SUBTYPES = ['I Na (Rare)',
#  'I Ca (Rare)',
#  'I K (Leak)',
#  'I Other (Rare)',
#  'I Na (Leak)',
#  'R Other (Rare)',
#  'I Cl ']
#
# - This is the google sheet: https://docs.google.com/spreadsheets/d/1gZ9pdoGwL_jVwC8APBZ_zb0jzLwl2hg3hIdfmLLEmRY/edit?gid=235253285#gid=235253285

# %%
#count_df  = get_count_df(ant_df_long, ['type', 'original_subtype_label'])
#View(count_df)

# %%
#count_df  = get_count_df(ant_df_long, ['type', 'original_subtype_label'])
count_df2 = get_count_df(ant_df_long, ['type', 'new_subtype_label'])
RARE_SUBTYPES_INNA = count_df2.sort_values(['type','new_subtype_label'], ascending=[True, False]).query("count <= 10")["new_subtype_label"].to_list()

# %%
RARE_SUBTYPES_INNA
# Out:
# ['I Ca (Rare)',
#  'I Cl ',
#  'I K (Leak)',
#  'I Na (Leak)',
#  'I Other (Transporter)',
#  'R Other (Rare)']

# %%
RARE_SUBTYPES_GPT
# Out:
# ['I K (Leak)', 'I Cl ', 'R Other (Rare)', 'I Na (Rare)', 'I Na (Leak)']

# %%
RARE_SUBTYPES = list(set(RARE_SUBTYPES_INNA + RARE_SUBTYPES_GPT))

# %%
RARE_SUBTYPES
# Out:
# ['I Cl ',
#  'I Na (Leak)',
#  'I Other (Transporter)',
#  'I Na (Rare)',
#  'I Ca (Rare)',
#  'I K (Leak)',
#  'R Other (Rare)']

# %%
#count_df2.style.apply(highlight_rare_rows, axis=1)
#todo: should we remove those < 10?
#rare_types = count_df2.query('count<10').sort_values('overall_pct', ascending=False)

# %% [markdown]
# # Feature Engineering

# %%
#ant_df_long[ant_df_long["new_subtype_label"].isna()].sort_values('row_id')

# %%
import re

# Regex patterns (non-capturing; match at line start with MULTILINE)
pattern_any = r'^\s*(?:INCLUDE\s+"[^"]+"|#include\s*[<"][^">]+[>"])'
pattern_cap = r'^\s*(?:INCLUDE\s+"[^"]+")'

# json_df2 build
json_df2 = (
    json_df
    .merge(ant_df_long, on=["row_id", "file_hash"], how="inner")
    .assign(
        mod_name = lambda df: df["url"].apply(get_fname),
        suffix = lambda df: df["content"].apply(get_suffix),
        read_ion = lambda df: df["content"].apply(get_read_ion),
        read_ion2 = lambda df: df["read_ion"].apply(
            lambda ion_list: list(set(map_ion(ion) for ion in ion_list)) if isinstance(ion_list, list) else []
        ),
        write_ion = lambda df: df["content"].apply(get_write_ion),
        write_ion2 = lambda df: df["write_ion"].apply(
            lambda ion_list: list(set(map_ion(ion) for ion in ion_list)) if isinstance(ion_list, list) else []
        ),
        parameter = lambda df: df["content"].apply(get_parameter),
        state = lambda df: df["content"].apply(get_derivative),
        net_receive = lambda df: df["content"].apply(get_net_receive),
        point_process = lambda df: df["content"].apply(get_point_process),
        nonspecific_current = lambda df: df["content"].apply(get_nonspecific_current),

        # Discrete features
        states_count = lambda df: df["state"].apply(lambda x: len(x) if isinstance(x, list) else 0),

        # Binary features
        clamp_yn = lambda df: df.apply(lambda row: has_electrode_or_clamp(row["mod_name"], row["content"]), axis=1),
        suffix_yn = lambda df: df["suffix"].apply(
            lambda x: 1 if isinstance(x, list) and len(x) > 0 else (0 if pd.isna(x) or x == "none" else 1)
        ),
        point_process_yn = lambda df: df["point_process"].apply(lambda x: 1 if pd.notna(x) else 0),
        net_receive_yn = lambda df: df["net_receive"].apply(
            lambda x: 1 if isinstance(x, list) and len(x) > 0 else (1 if pd.notna(x) else 0)
        ),
        i_nonspecific_yn = lambda df: df["nonspecific_current"].apply(
            lambda x: 1 if isinstance(x, list) and len(x) > 0 else (1 if pd.notna(x) else 0)
        ),
        not_ion_channel_yn = lambda df: (
            (df["suffix_yn"] == 0) & df["read_ion"].isna() & df["write_ion"].isna() & df["nonspecific_current"].isna()
        ).astype(int),
        not_receptor_yn = lambda df: (
            (df["point_process_yn"] == 0) & (df["net_receive_yn"] == 0)
        ).astype(int),

        has_mg_yn = lambda df: df["content"].apply(has_mg),
        volt_min = lambda df: df["content"].apply(lambda x: extract_voltage_extrema(x)[0]),
        volt_max = lambda df: df["content"].apply(lambda x: extract_voltage_extrema(x)[1]),

        # Include indicators and line counts
        has_include_yn = lambda df: df['content'].str.contains(pattern_any, case=False, na=False, flags=re.MULTILINE),
        has_include_cap_yn = lambda df: df['content'].str.contains(pattern_cap, case=True, na=False, flags=re.MULTILINE),
     #   line_unadj_count = lambda df: df['content'].fillna("").str.count(r'\n') + (df['content'].notna().astype(int)),
     #   line_adj_count = lambda df: df['content'].apply(count_code_lines),

        # Architecture presence (uncomment if desired)
        # has_x86_64 = lambda df: df['url'].str.contains(r"x86_64", case=False, na=False),
    )
    .reset_index(drop=True)
)
# Out:
# 	a = 0.2*(-1.0*v+19.26)/(exp((-1.0*v+19.26)/10.0)-1.0)
# 	a = 0.2*(-v+19.26)/(exp((-v+19.26)/10.0)-1.0)
# 	alp = 15.69*(-1.0*v+81.5)/(exp((-1.0*v+81.5)/10.0)-1.0)
# 	alp = 15.69*(-v+81.5)/(exp((-v+81.5)/10.0)-1.0)
# 	alpm = 0.1967*(-1.0*v+19.88)/(exp((-1.0*v+19.88)/10.0)-1.0)
# 	alpm = 0.1967*(-v+19.88)/(exp((-v+19.88)/10.0)-1.0)
# 	alpm = 0.1967*(-1.0*v+19.88)/(exp((-1.0*v+19.88)/10.0)-1.0)
# 	alpm = 0.1967*(-v+19.88)/(exp((-v+19.88)/10.0)-1.0)
# 	a = 0.2*(-1.0*v+19.26)/(exp((-1.0*v+19.26)/10.0)-1.0)
# 	a = 0.2*(-v+19.26)/(exp((-v+19.26)/10.0)-1.0)
# 	a = 0.2*(-1.0*v+19.26)/(exp((-1.0*v+19.26)/10.0)-1.0)
# 	a = 0.2*(-v+19.26)/(exp((-v+19.26)/10.0)-1.0)
# 	alp = scaletau*15.69*(-1.0*v-shiftm+81.5)/(exp((-1.0*v-shiftm+81.5)/10.0)-1.0)
# 	alp = scaletau*15.69*(-v-shiftm+81.5)/(exp((-v-shiftm+81.5)/10.0)-1.0)
# 	alpm = 0.1967*(-1.0*v+19.88)/(exp((-1.0*v+19.88)/10.0)-1.0)
# 	alpm = 0.1967*(-v+19.88)/(exp((-v+19.88)/10.0)-1.0)
# 	alp = 15.69*(-1.0*v+81.5)/(exp((-1.0*v+81.5)/10.0)-1.0)
# 	alp = 15.69*(-v+81.5)/(exp((-v+81.5)/10.0)-1.0)
# 	alp = 15.69*(-1.0*v+81.5)/(exp((-1.0*v+81.5)/10.0)-1.0)
# 	alp = 15.69*(-v+81.5)/(exp((-v+81.5)/10.0)-1.0)
# 	alp = 15.69*(-1.0*v+81.5)/(exp((-1.0*v+81.5)/10.0)-1.0)
# 	alp = 15.69*(-v+81.5)/(exp((-v+81.5)/10.0)-1.0)
# 	alp = 15.69*(-1.0*v+81.5)/(exp((-1.0*v+81.5)/10.0)-1.0)
# 	alp = 15.69*(-v+81.5)/(exp((-v+81.5)/10.0)-1.0)
#     alpm = 0.1967*(-1.0*v+19.88)/(exp((-1.0*v+19.88)/10.0)-1.0)
#     alpm = 0.1967*(-v+19.88)/(exp((-v+19.88)/10.0)-1.0)
# 	alpm = 0.1967*(-1.0*v+19.88)/(exp((-1.0*v+19.88)/10.0)-1.0)
# 	alpm = 0.1967*(-v+19.88)/(exp((-v+19.88)/10.0)-1.0)
# 	a = 0.2*(-1.0*v+19.26)/(exp((-1.0*v+19.26)/10.0)-1.0)
# 	a = 0.2*(-v+19.26)/(exp((-v+19.26)/10.0)-1.0)
# 	a = 0.2*(-1.0*v+19.26)/(exp((-1.0*v+19.26)/10.0)-1.0)
# 	a = 0.2*(-v+19.26)/(exp((-v+19.26)/10.0)-1.0)
# 	a = 0.2*(-1.0*v+19.26)/(exp((-1.0*v+19.26)/10.0)-1.0)
# 	a = 0.2*(-v+19.26)/(exp((-v+19.26)/10.0)-1.0)
# 	a = 0.2*(-1.0*v+19.26)/(exp((-1.0*v+19.26)/10.0)-1.0)
# 	a = 0.2*(-v+19.26)/(exp((-v+19.26)/10.0)-1.0)
# 	alp = 15.69*(-1.0*v+81.5)/(exp((-1.0*v+81.5)/10.0)-1.0)
# 	alp = 15.69*(-v+81.5)/(exp((-v+81.5)/10.0)-1.0)
# 	alpm = 0.1967*(-1.0*v+19.88)/(exp((-1.0*v+19.88)/10.0)-1.0)
# 	alpm = 0.1967*(-v+19.88)/(exp((-v+19.88)/10.0)-1.0)
# 	alpm = 0.1967*(-1.0*v+19.88)/(exp((-1.0*v+19.88)/10.0)-1.0)
# 	alpm = 0.1967*(-v+19.88)/(exp((-v+19.88)/10.0)-1.0)
# 	a = 0.2*(-1.0*v+19.26)/(exp((-1.0*v+19.26)/10.0)-1.0)
# 	a = 0.2*(-v+19.26)/(exp((-v+19.26)/10.0)-1.0)
# 	a = 0.2*(-1.0*v+19.26)/(exp((-1.0*v+19.26)/10.0)-1.0)
# 	a = 0.2*(-v+19.26)/(exp((-v+19.26)/10.0)-1.0)
# 	alp = scaletau*15.69*(-1.0*v-shiftm+81.5)/(exp((-1.0*v-shiftm+81.5)/10.0)-1.0)
# 	alp = scaletau*15.69*(-v-shiftm+81.5)/(exp((-v-shiftm+81.5)/10.0)-1.0)
# 	alpm = 0.1967*(-1.0*v+19.88)/(exp((-1.0*v+19.88)/10.0)-1.0)
# 	alpm = 0.1967*(-v+19.88)/(exp((-v+19.88)/10.0)-1.0)
# 	alp = 15.69*(-1.0*v+81.5)/(exp((-1.0*v+81.5)/10.0)-1.0)
# 	alp = 15.69*(-v+81.5)/(exp((-v+81.5)/10.0)-1.0)
# 	alp = 15.69*(-1.0*v+81.5)/(exp((-1.0*v+81.5)/10.0)-1.0)
# 	alp = 15.69*(-v+81.5)/(exp((-v+81.5)/10.0)-1.0)
# 	alp = 15.69*(-1.0*v+81.5)/(exp((-1.0*v+81.5)/10.0)-1.0)
# 	alp = 15.69*(-v+81.5)/(exp((-v+81.5)/10.0)-1.0)
# 	alp = 15.69*(-1.0*v+81.5)/(exp((-1.0*v+81.5)/10.0)-1.0)
# 	alp = 15.69*(-v+81.5)/(exp((-v+81.5)/10.0)-1.0)
#     alpm = 0.1967*(-1.0*v+19.88)/(exp((-1.0*v+19.88)/10.0)-1.0)
#     alpm = 0.1967*(-v+19.88)/(exp((-v+19.88)/10.0)-1.0)
# 	alpm = 0.1967*(-1.0*v+19.88)/(exp((-1.0*v+19.88)/10.0)-1.0)
# 	alpm = 0.1967*(-v+19.88)/(exp((-v+19.88)/10.0)-1.0)
# 	a = 0.2*(-1.0*v+19.26)/(exp((-1.0*v+19.26)/10.0)-1.0)
# 	a = 0.2*(-v+19.26)/(exp((-v+19.26)/10.0)-1.0)
# 	a = 0.2*(-1.0*v+19.26)/(exp((-1.0*v+19.26)/10.0)-1.0)
# 	a = 0.2*(-v+19.26)/(exp((-v+19.26)/10.0)-1.0)
# 	a = 0.2*(-1.0*v+19.26)/(exp((-1.0*v+19.26)/10.0)-1.0)
# 	a = 0.2*(-v+19.26)/(exp((-v+19.26)/10.0)-1.0)

# %%
json_df2.query("row_id == 871")
# Out:
#      row_id                                          file_hash  \
# 676     871  3d746f710fc8d0b06be3d8c0771ab280046d57d60ddc45...
#
#                                                raw_sha  count  \
# 676  0004eaa8aca0eec6b9b07ab8a16e7017f0afa1fed168e3...      1
#
#                                                    url  \
# 676  https://modeldb.science/230137?tab=2&file=SinK...
#
#                                           download_url  \
# 676  https://modeldb.science/getModelFile?model=230...
#
#                                                content error_code  type  \
# 676  TITLE Nav1.2 ionic voltage-gated channel with ...       None  I Na
#
#        subtype_confidence               notes_free_text  Unnamed: 17  \
# 676  3 - Highly confident  8/9: Updated confidence. NaG          NaN
#
#      Unnamed: 18  Unnamed: 19 Unnamed: 20 original_subtype_label  \
# 676          NaN          NaN         NaN         I Na (General)
#
#     original_type_label new_subtype_label gpt_only mod_name   suffix read_ion  \
# 676                I Na    I Na (General)           Nav12_a  [na12a]    [ena]
#
#     read_ion2 write_ion write_ion2  \
# 676    [e_na]      None         []
#
#                                              parameter  \
# 676  {'gbar': 0.1, 'C1C2b2': 16.0, 'C1C2v2': -5.0, ...
#
#                         state net_receive point_process nonspecific_current  \
# 676  [C1, C2, O1, O2, I1, I2]        None          None                None
#
#      states_count  clamp_yn  suffix_yn  point_process_yn  net_receive_yn  \
# 676             6         0          1                 0               0
#
#      i_nonspecific_yn  not_ion_channel_yn  not_receptor_yn  has_mg_yn  \
# 676                 0                   0                1          0
#
#      volt_min  volt_max  has_include_yn  has_include_cap_yn
# 676       NaN       NaN           False               False

# %%
# Use MultiLabelBinarizer separately for read and write ions
# Reset index before merging to avoid index mismatches
mlb_read = MultiLabelBinarizer()
read_df = pd.DataFrame(mlb_read.fit_transform(json_df2['read_ion2']), 
                                columns=[f'read_{col}_yn' for col in mlb_read.classes_]).reset_index(drop=True)

mlb_write = MultiLabelBinarizer()
write_df = pd.DataFrame(mlb_write.fit_transform(json_df2['write_ion2']), 
                                 columns=[f'write_{col}_yn' for col in mlb_write.classes_]).reset_index(drop=True)

# %%
#note: the ones with missing subtype labels are the rare subtypes
#json_df3[json_df3["new_subtype_label"].isna()].shape
json_df3 = json_df2.drop(columns=['read_ion2', 'write_ion2']).join(read_df, rsuffix='_read_dup').join(write_df, rsuffix='_write_dup').dropna(subset=["new_subtype_label"])

# %%
json_df3.shape
# Out:
# (1003, 76)

# %%
#json_df3

# %%
#Number of mod files in sample that have features derived from simulation
json_df3.merge(sim_df, how="inner", on="file_hash").shape[0]
# Out:
# 569

# %%
json_df4 = json_df3.merge(sim_df, how="left", on="file_hash")

# %%
json_df4.columns
# Out:
# Index(['row_id', 'file_hash', 'raw_sha', 'count', 'url', 'download_url',
#        'content', 'error_code', 'type', 'subtype_confidence',
#        ...
#        'ica_interval1_time_min_to_90_max_simfeat',
#        'ica_interval1_time_max_to_90_min_simfeat',
#        'ica_interval1_initial_val_simfeat', 'ica_interval1_max_val_simfeat',
#        'ica_interval1_min_val_simfeat',
#        'ica_interval2_time_to_90_recovery_simfeat',
#        'ica_interval2_recovery_start_val_simfeat',
#        'ica_interval2_final_val_simfeat', 'ica_interval2_max_val_simfeat',
#        'ica_interval2_min_val_simfeat'],
#       dtype='object', length=126)

# %%
EXTERNAL_VALIDATION_SET = json_df4.query("row_id > 1000")["file_hash"].tolist()

# %%
sim_df.shape
# Out:
# (569, 51)

# %%
print("Total shape", json_df4.shape)
print("Total unique currents/receptors", json_df4["row_id"].nunique())
# Out:
# Total shape (1003, 126)
# Total unique currents/receptors 1003

# %%
df_pre = json_df4.set_index('file_hash').filter(regex=r'(_yn|_count|new_subtype_label|volt_min|volt_max|_simfeat)$')

# %%
json_df4["type"].value_counts()
# Out:
# type
# I K         324
# Neither     232
# I Na        147
# I Ca        113
# Receptor    104
# I H          47
# I Other      35
# I Cl          1
# Name: count, dtype: int64

# %%
df_pre["new_subtype_label"].value_counts()
# Out:
# new_subtype_label
# Z Neither                  232
# I K (A-type)                93
# I Na (Transient)            85
# I K (Delayed Rectifier)     80
# I Ca (HVA)                  72
# I K (Ca-activated)          68
# I H                         47
# I K (M-type)                40
# R Glutamate (NMDA)          39
# I K (Rare)                  39
# R GABA                      33
# I Ca (T-type LT)            31
# R Glutamate (AMPA)          31
# I Na (Rare)                 23
# I Na (Persistent)           22
# I Other (Leak)              15
# I Na (General)              15
# I Other (Rare)              11
# I Ca (Rare)                 10
# I Other (Transporter)        9
# I K (Leak)                   4
# I Na (Leak)                  2
# I Cl                         1
# R Other (Rare)               1
# Name: count, dtype: int64

# %%
df_pre["rare_subtype"] = df_pre["new_subtype_label"].isin(RARE_SUBTYPES)
df_pre.to_csv("../data/pipeline/preprocessed.csv")

# %% [markdown]
# ## Which samples have sim_feat?

# %%
#df_pre[["type", "voltage_10_simfeat"]].query("voltage_10_simfeat.notnull()").type.value_counts()

# %%
#df_pre[["new_subtype_label", "voltage_10_simfeat"]].query("voltage_10_simfeat.notnull()").new_subtype_label.value_counts()

# %% [markdown]
# ## Which samples do not have sim_feat?

# %%
#df_pre[["type", "voltage_10_simfeat"]].query("voltage_10_simfeat.isnull()").type.value_counts()

# %% [markdown]
# - We would fix 128 samples

# %%
#df_pre[["new_subtype_label", "voltage_10_simfeat"]].query("voltage_10_simfeat.isnull()").new_subtype_label.value_counts()

# %%
#df_pre[["new_subtype_label", "voltage_10_simfeat", "type"]].query("voltage_10_simfeat.isnull() and type == 'I H'")
# ❌ will raise an error due to `.isnull()` usage

# ✅ Use this instead:
#View(df_pre[["new_subtype_label", "voltage_10_simfeat", "type"]].query("voltage_10_simfeat.isnull() and type == 'I H'"))

# %%
#View(ant_df_long.query("file_hash == '4e3f8b76527532d56c76025e03c24814158dc0396cce61bda61f42becabd3fe8'"))

# %%
#df_pre[["new_subtype_label", "voltage_10_simfeat"]].query("voltage_10_simfeat.isnull() and type == 'I H'")

# %%
#df_pre[df_pre["voltage_10_simfeat"].isnull() & (df_pre["new_subtype_label"] == "Z Neither")].index.to_list()

# %%
json_df3[json_df3.new_subtype_label.isna()]
json_df3[json_df3.type.isna()]
# Out:
# Empty DataFrame
# Columns: [row_id, file_hash, raw_sha, count, url, download_url, content, error_code, type, subtype_confidence, notes_free_text, Unnamed: 17, Unnamed: 18, Unnamed: 19, Unnamed: 20, original_subtype_label, original_type_label, new_subtype_label, gpt_only, mod_name, suffix, read_ion, write_ion, parameter, state, net_receive, point_process, nonspecific_current, states_count, clamp_yn, suffix_yn, point_process_yn, net_receive_yn, i_nonspecific_yn, not_ion_channel_yn, not_receptor_yn, has_mg_yn, volt_min, volt_max, has_include_yn, has_include_cap_yn, read_ca_i_yn, read_ca_o_yn, read_cl_i_yn, read_cl_o_yn, read_e_ca_yn, read_e_k_yn, read_e_na_yn, read_e_other_yn, read_i_cal_yn, read_i_cl_yn, read_i_k_yn, read_i_na_yn, read_i_other_yn, read_k_i_yn, read_k_o_yn, read_na_i_yn, read_na_o_yn, read_other_i_yn, read_other_o_yn, write_ca_i_yn, write_ca_o_yn, write_cl_i_yn, write_cl_o_yn, write_i_cal_yn, write_i_cl_yn, write_i_k_yn, write_i_na_yn, write_i_other_yn, write_k_i_yn, write_k_o_yn, write_na_i_yn, write_na_o_yn, write_other_i_yn, write_other_o_yn, write_unknown_yn]
# Index: []

# %%
# === Create ../data/pipeline directory if it doesn't exist ===
pipeline_dir = os.path.abspath(os.path.join("..", "data", "pipeline"))
os.makedirs(pipeline_dir, exist_ok=True)

# === 1. Save failed_neither.pkl ===
failed_neither = df_pre[df_pre["voltage_simfeat"].isnull() &
                        (df_pre["new_subtype_label"] == "Z Neither")].index.to_list()

failed_neither_path = os.path.join(pipeline_dir, "failed_neither.pkl")

with open(failed_neither_path, "wb") as f:
    pickle.dump(failed_neither, f)

print(f"✅ Saved {len(failed_neither)} indices to {failed_neither_path}")

# === 2. Save failed_excluded.pkl ===
a = set(raw_ant_df_wide.file_hash)
b = set(df_pre.index)
failed_excluded = list(a - b)

failed_excluded_path = os.path.join(pipeline_dir, "failed_excluded.pkl")

with open(failed_excluded_path, "wb") as f:
    pickle.dump(failed_excluded, f)

print(f"✅ Saved {len(failed_excluded)} excluded items to {failed_excluded_path}")
# Out:
# ✅ Saved 232 indices to /vast/palmer/scratch/mcdougal/imc33/mod-extract/data/pipeline/failed_neither.pkl
# ✅ Saved 294 excluded items to /vast/palmer/scratch/mcdougal/imc33/mod-extract/data/pipeline/failed_excluded.pkl

# %%
# Save your variables manually
with open("../data/pipeline/rare_subtypes.pkl", "wb") as f:
    pickle.dump(RARE_SUBTYPES, f)

with open("../data/pipeline/external_validation_set.pkl", "wb") as f:
    pickle.dump(EXTERNAL_VALIDATION_SET, f)

with open("../data/pipeline/annotated_samples.pkl", "wb") as f:
    pickle.dump(ANNOTATED_SAMPLES, f)
