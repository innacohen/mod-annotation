# %%
from _utils import *
METADATA_FP = os.path.join(RAW_DATA_DIR, "model_db_metadata.json")
json_df = pd.read_json(METADATA_FP)

# %%
json_df.columns
# Out:
# Index(['row_id', 'file_hash', 'raw_sha', 'count', 'url', 'model_id',
#        'created_date', 'download_url', 'filename', 'content', 'error_code',
#        'has_include', 'download_date'],
#       dtype='object')
