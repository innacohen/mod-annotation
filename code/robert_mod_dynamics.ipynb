# %%
from neuron import h
print('kap' in dir(h))  # should now print True
# Out:
# ...
# --No graphics will be displayed.
# True

# %%
from get_mod_dynamics import *

# %%
results_kaprox = run_sim("kaprox.mod", v=20, doplot=True)
# Out:
# temperature = 24.0
# {'ica': {'interval1': {'initial_val': None,
#                        'max_val': None,
#                        'min_val': None,
#                        'time_max_to_90_min': None,
#                        'time_min_to_90_max': None,
#                        'time_to_90_max': None,
#                        'time_to_90_min': None},
#          'interval2': {'final_val': None,
#                        'max_val': None,
#                        'min_val': None,
#                        'recovery_start_val': None,
#                        'time_to_90_recovery': None}},
#  'ik': {'interval1': {'initial_val': 4.353205387253223e-05,
#                       'max_val': 0.13454718256780168,
#                       'min_val': 4.353205387253223e-05,
#                       'time_max_to_90_min': 49.625000000180535,
#                       'time_min_to_90_max': 6.025000000021919,
#                       'time_to_90_max': 6.025000000021919,
# ...

# %%
# !git add .
# !git commit -m "was able to run in bash"
# !git push
# Out:
# [main bbb4499] was able to run in bash
#  9 files changed, 112 insertions(+), 19 deletions(-)
#  create mode 100644 code/cal_response_plot.png
#  create mode 100644 code/kap_response_plot.png
# Enumerating objects: 23, done.
# Counting objects: 100% (23/23), done.
# Delta compression using up to 64 threads
# Compressing objects: 100% (12/12), done.
# Writing objects: 100% (13/13), 309.48 KiB | 13.46 MiB/s, done.
# Total 13 (delta 5), reused 0 (delta 0), pack-reused 0
# remote: Resolving deltas: 100% (5/5), completed with 5 local objects.
# To github.com:innacohen/mod-extract.git
#    b6e67e7..bbb4499  main -> main

# %%
results_cal2 = run_sim("cal2.mod", v=10, doplot=True)

# %%
from neuron import h
print('kap' in dir(h))  # Should return True if it's compiled

# %%
get_suffix_name("kaprox.mod")
